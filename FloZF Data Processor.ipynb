# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_table('Desktop/Data from week of 8_5_2020/sample_417.pfl', header = 15)
df
# Out:
#     Time (s)  Photons (counts)
# 0     0.0270              26.0
# 1     0.5120              60.0
# 2     1.0165               0.0
# 3     1.5150              -2.0
# 4     2.0115              34.0
# 5     2.5165             -58.0
# 6     3.0150             -35.0
# 7     3.5125           15961.0
# 8     4.0180           64790.0
# 9     4.5150           66486.0
# 10    5.0130           66231.0
# 11    5.5185           61926.0
# 12    6.0150           61568.0
# 13    6.5120           61172.0
# 14    7.0185           61581.0
# 15    7.5160           61125.0
# 16    8.0125           59899.0
# 17    8.5185           60809.0
# 18    9.0165           60282.0
# 19    9.5135           59776.0
# 20   10.0105           60508.0
# 21   10.5170           60047.0
# 22   11.0145           60393.0
# 23   11.5105           60736.0
# 24   12.0165           58900.0
# 25   12.5145           60297.0
# 26   13.0110           59317.0
# 27   13.5170           58624.0
# 28   14.0145           59050.0
# ...

# %%
time = df['Time (s)']
counts = df['Photons (counts)']

# %%
plt.plot(time, counts,'k')
plt.xlabel('Time (s)')
plt.ylabel('Photons (counts)')
plt.title('')
# Out:
# Text(0.5, 1.0, '')
